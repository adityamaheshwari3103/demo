# %% [markdown]
# ## basic python code

# %%
print("hello world")
# Out:
# hello world

# %%
def double (num):
    return (num**2)
double(2)
double(3)
# Out:
# 9

# %%
def square (num):
    return num*num
square(3)
# Out:
# 9

# %%
website = "apple.com"
print(website)

# assigning a new value to website
website = "programiz.com"

print(website)
# Out:
# apple.com
# programiz.com

# %%
aditya = "maheshwari"
print(aditya)
print("aditya")
aditya ="kanu"
print(aditya)
print("aditya")
# Out:
# maheshwari
# aditya
# kanu
# aditya

# %%
a,b,c = 10,20.32,"aditya"
print(a,b,c)
# Out:
# 10 20.32 aditya

# %%
drink = "Available"
food = None

def menu(x):
    if x == drink:
        print(drink)
    else:
        print(food)

menu(drink)
menu(food)
# Out:
# Available
# None

# %%
aditya = "adi"
maheshwari = "mahesh"

def menu(x):
    if x==aditya:
        print(aditya)
    else:
        print(maheshwari)
        
menu(aditya)
menu(maheshwari)
# Out:
# adi
# mahesh

# %%
fruits = ["apple", "mango", "orange"] #list
numbers = (1, 2, 3) #tuple
alphabets = {'a':'apple', 'b':'ball', 'c':'cat'} #dictionary
vowels = {'a', 'e', 'i' , 'o', 'u'} #set

print(fruits)
print(numbers)
print(alphabets)
print(vowels)
# Out:
# ['apple', 'mango', 'orange']
# (1, 2, 3)
# {'a': 'apple', 'b': 'ball', 'c': 'cat'}
# {'u', 'a', 'i', 'o', 'e'}

# %%
aditya = ["sab","jskhk","dbsh"] #list
maheshwari = (1,2,3,45,5) #tuple
kanu = {'a':'apple' , 'b':'banana','c':'carrot'} #dictionary
vowel = {"a","e","i","o","u"} # set
print(aditya,maheshwari,kanu,vowel)
# Out:
# ['sab', 'jskhk', 'dbsh'] (1, 2, 3, 45, 5) {'a': 'apple', 'b': 'banana', 'c': 'carrot'} {'u', 'a', 'i', 'o', 'e'}

# %%
a=5.0
print(a ,"is of type", type(a))
# Out:
# 5.0 is of type <class 'float'>

# %%
adi=[1,2,34,5,6,7,88,8,]
print(adi[0:2])
print(adi[:3])
print(adi[:-3])
adi[2]= "aditya"
print(adi)
# Out:
# [1, 2]
# [1, 2, 34]
# [1, 2, 34, 5, 6]
# [1, 2, 'aditya', 5, 6, 7, 88, 8]

# %%
di=(1,2,34,5,6,7,88,8,)
print(di)
print(di[:-1])
# Out:
# (1, 2, 34, 5, 6, 7, 88, 8)
# (1, 2, 34, 5, 6, 7, 88)

# %%
d = {1:'value','key':2}
print(type(d))

print("d[1] = ", d[1])

print("d['key'] = ", d['key'])

# Generates error
print("d[2] = ", d[2])
# Out:
# <class 'dict'>
# d[1] =  value
# d['key'] =  2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9188/4116809694.py in <module>
#       7
#       8 # Generates error
# ----> 9 print("d[2] = ", d[2])
#
# KeyError: 2

# %%
list("aditya")
# Out:
# ['a', 'd', 'i', 't', 'y', 'a']

# %%
print('i love {0} and butter {1}' .format ('bread','butter'))
# Out:
# i love bread and butter butter

# %%
print("i like {0} and {1}".format("adi","asd"))
# Out:
# i like adi and asd

# %%
x=123.3444
print("the value of x: % 3.3f" %x)
# Out:
# the value of x:  123.344

# %%
num = int(input("the number is "))
print(type(num))
# Out:
# the number is 3
# <class 'int'>

# %%
from math import sqrt
a = float(input("type the number"))
print("square of the number is " , sqrt(a))
# Out:
# type the number36
# square of the number is  6.0

# %%
# %%timeit
l = []
for i in range(1000):
    l.append(i*i)
# Out:
# 290 µs ± 3.94 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
l = list(map(lambda x: x*x, range(1000)))
# Out:
# 324 µs ± 7.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ######  List = [1,2,3,4,5,.., 1000000000.]
# ###### Generator = function

# %%
l = [x*x for x in range(1000)]    # List Comprehension

# l = []
# for x in range(1000):
#     l.append(x*x)

# %%
l = (x*x for x in range(10000000000))

# %%
l.__next__()
# Out:
# 1681

# %%
def abc():
    return 


def abc():
    yield

# %%
a = [1,2]
b = [3,4]

c = a + b
c.pop(2), c
# Out:
# (3, [1, 2, 4])

# %%
a = (1,2)
b = (3,4)

a + b
# Out:
# (1, 2, 3, 4)

# %%
#"abcdefghi024"[3:6], 
#l=[i for i in "abcdefghi024"]
#l
l= list("aditya")
l
# Out:
# ['a', 'd', 'i', 't', 'y', 'a']

# %%
d = {}
for key, value in enumerate(range(0,20000,2)):
    d.update({key:value})

# %%
# %%timeit
c = {}
for key, value in d.items():
    c.update({value:key})
# Out:
# 6.64 ms ± 194 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
#%%timeit
{value:key for key, value in enumerate(range(0,20000,2))} # dict comprehension
# Out:
# {0: 0,
#  2: 1,
#  4: 2,
#  6: 3,
#  8: 4,
#  10: 5,
#  12: 6,
#  14: 7,
#  16: 8,
#  18: 9,
#  20: 10,
#  22: 11,
#  24: 12,
#  26: 13,
#  28: 14,
#  30: 15,
#  32: 16,
#  34: 17,
#  36: 18,
#  38: 19,
#  40: 20,
#  42: 21,
#  44: 22,
#  46: 23,
#  48: 24,
#  50: 25,
#  52: 26,
#  54: 27,
#  56: 28,
#  58: 29,
#  60: 30,
#  62: 31,
#  64: 32,
#  66: 33,
#  68: 34,
#  70: 35,
#  72: 36,
#  74: 37,
#  76: 38,
#  78: 39,
#  80: 40,
#  82: 41,
#  84: 42,
#  86: 43,
#  88: 44,
#  90: 45,
#  92: 46,
#  94: 47,
#  96: 48,
#  98: 49,
#  100: 50,
#  102: 51,
#  104: 52,
#  106: 53,
#  108: 54,
#  110: 55,
#  112: 56,
#  114: 57,
#  116: 58,
#  118: 59,
#  120: 60,
#  122: 61,
#  124: 62,
#  126: 63,
#  128: 64,
#  130: 65,
#  132: 66,
#  134: 67,
#  136: 68,
#  138: 69,
#  140: 70,
#  142: 71,
#  144: 72,
#  146: 73,
#  148: 74,
#  150: 75,
#  152: 76,
#  154: 77,
#  156: 78,
#  158: 79,
#  160: 80,
#  162: 81,
#  164: 82,
#  166: 83,
#  168: 84,
#  170: 85,
#  172: 86,
#  174: 87,
# ...

# %%
l = list(range(1,100))

l.index(50)
# Out:
# 49

# %%
# Indexing
#

# %%
# int, float, char, string
#

# %%
"//".join(["ab", "def"])

"//".join(["ab", "def", "ab", "def","ab", "def"])
# Out:
# 'ab//def//ab//def//ab//def'

# %%
l = ["ab", "def", "ab", "def","ab", "def"]
s = l[0]
for i in l[1:]:
    s += "//" + i
    
print(s)
# Out:
# ab//def//ab//def//ab//def

# %%
{key:value for key, value in enumerate(range(0,1000,2))}
# Out:
# {0: 0,
#  1: 2,
#  2: 4,
#  3: 6,
#  4: 8,
#  5: 10,
#  6: 12,
#  7: 14,
#  8: 16,
#  9: 18,
#  10: 20,
#  11: 22,
#  12: 24,
#  13: 26,
#  14: 28,
#  15: 30,
#  16: 32,
#  17: 34,
#  18: 36,
#  19: 38,
#  20: 40,
#  21: 42,
#  22: 44,
#  23: 46,
#  24: 48,
#  25: 50,
#  26: 52,
#  27: 54,
#  28: 56,
#  29: 58,
#  30: 60,
#  31: 62,
#  32: 64,
#  33: 66,
#  34: 68,
#  35: 70,
#  36: 72,
#  37: 74,
#  38: 76,
#  39: 78,
#  40: 80,
#  41: 82,
#  42: 84,
#  43: 86,
#  44: 88,
#  45: 90,
#  46: 92,
#  47: 94,
#  48: 96,
#  49: 98,
#  50: 100,
#  51: 102,
#  52: 104,
#  53: 106,
#  54: 108,
#  55: 110,
#  56: 112,
#  57: 114,
#  58: 116,
#  59: 118,
#  60: 120,
#  61: 122,
#  62: 124,
#  63: 126,
#  64: 128,
#  65: 130,
#  66: 132,
#  67: 134,
#  68: 136,
#  69: 138,
#  70: 140,
#  71: 142,
#  72: 144,
#  73: 146,
#  74: 148,
#  75: 150,
#  76: 152,
#  77: 154,
#  78: 156,
#  79: 158,
#  80: 160,
#  81: 162,
#  82: 164,
#  83: 166,
#  84: 168,
#  85: 170,
#  86: 172,
#  87: 174,
# ...

# %%
number = float(input("value:"))
if number > 0 :
    print("the %2.3f is positive no" %number)
elif number < 0:
    print("the number is negative number")
else:
    print("the number is zero")
# Out:
# value:3542.342
# the 3542.342 is positive no

# %%
'''In this program, we input a number
check if the number is positive or
negative or zero and display
an appropriate message
This time we use nested if statement'''

num = float(input("Enter a number: "))
if num >= 0:
    if num == 0:
        print("Zero")
    else:
        print("Positive number")
else:
    print("Negative number")
# Out:
# Enter a number: 3334
# Positive number

# %%
def multiply(x):
    return x*3
multiply(3)
# Out:
# 9

# %%
list_ = [1,2,4,5,6,7788,7,5,7,5]
list(map(multiply,list_))
# Out:
# [3, 6, 12, 15, 18, 23364, 21, 15, 21, 15]

# %%
list(map(lambda x:x*3,list_))
# Out:
# [3, 6, 12, 15, 18, 23364, 21, 15, 21, 15]

# %%
f=lambda y: y**2

# %%
f(5)
# Out:
# 25

# %%
list(filter(lambda x: x>4,list_))
# Out:
# [5, 6, 7788, 7, 5, 7, 5]

# %%
from functools import reduce

a = [(1,2),(4,5)]
reduce(lambda x,y:x+y,a), sum(a, ())
# Out:
# ((1, 2, 4, 5), (1, 2, 4, 5))

# %%
sum(list_)
# Out:
# 7830

# %%
## and or in not is

# %%
x = range(1,101)
sum(x)
# Out:
# 5050

# %%
30 in list_
# Out:
# False

# %%
x = 2
y =4
z = x

x is z
# Out:
# True

# %% [markdown]
# sum(range(1,11))

# %%
# %%timeit
sum(range(1,100000))
# Out:
# 7.19 ms ± 158 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
sum=0
for x in range (1,100000):
    sum += x


sum
# Out:
# 16.4 ms ± 285 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Out:
#   File "C:\Users\mahes\AppData\Local\Temp/ipykernel_31816/363547303.py", line 1
#     for val in ["c++"","python","java","dotnet","c","oracle"]:
#                         ^
# SyntaxError: invalid syntax

# %%
a = ['a','s','c','w','q']
# for x in range(0,len(a),2):
#     print(a[x])
not_to_print = ["s", "c"]

for i in a:
    if i in not_to_print:
        continue
        
    print(i)
# Out:
# a
# w
# q

# %%
a =list(range(1,50,4))
a.

# %%
b = tuple(a)
b.
# Out:
# 1

# %%
def fac(x):
    if(x==1):
        return(x)
    elif x<=0:
        print("invalid number")
     
    
    else:
        return(x*fac(x-1))
y=int(input("enter value"))

print("factorial of ",y,"is",fac(y))
# Out:
# enter value0
# invalid number
# factorial of  0 is None

# %%
def multiply(x):
    return x*2
multiply(3)

list_=[1,2,4,5,6,8,0]
list(map(multiply,list_))
# Out:
# [2, 4, 8, 10, 12, 16, 0]

# %%
list(map(lambda x:x**2,list_))
# Out:
# [1, 4, 16, 25, 36, 64, 0]

# %%
p=lambda x:x**x
p(4)
# Out:
# 256

# %%
s = list(filter(lambda x: (x%2==0),list_))
print(s)
# Out:
# [2, 4, 6, 8, 0]

# %%
a = 5

print(type(a))

print(type(5.0))

c = 5 + 3j
print(c + 3)

print(isinstance(c, complex))
# Out:
# <class 'int'>
# <class 'float'>
# (8+3j)
# True

# %%
import math as m
n = int(input("enter the value"))
x = m.factorial(n)
print("factorial of",n,"is",x)
# Out:
# enter the value8
# factorial of 8 is 40320

# %%
# define Python user-defined exceptions
class Error(Exception):
    """Base class for other exceptions"""
    pass


class ValueTooSmallError(Error):
    """Raised when the input value is too small"""
    pass


class ValueTooLargeError(Error):
    """Raised when the input value is too large"""
    pass


# you need to guess this number
number = 10

# user guesses a number until he/she gets it right
while True:
    try:
        i_num = int(input("Enter a number: "))
        if i_num < number:
            raise ValueTooSmallError
        elif i_num > number:
            raise ValueTooLargeError
        break
    except ValueTooSmallError:
        print("This value is too small, try again!")
        print()
    except ValueTooLargeError:
        print("This value is too large, try again!")
        print()

print("Congratulations! You guessed it correctly.")
# Out:
# Enter a number: 2
# This value is too small, try again!
#
# Enter a number: 6
# This value is too small, try again!
#
# Enter a number: 13
# This value is too large, try again!
#
# Enter a number: 10
# Congratulations! You guessed it correctly.
